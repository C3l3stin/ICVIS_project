# %% [markdown]
# ## Informations

# %% [markdown]
# This notebook only contains code with the pretrained YOLOv12 model on license plates detection.
# It was used on Colab.

# %%
import yaml


# Remplacez 'MonProjetYOLO' par le nom exact de votre dossier sur Google Drive
drive_path = '/content/drive/MyDrive/data'

data_config = {
    'path': drive_path,
    'train': 'images/train',
    'val': 'images/val',
    'names': {
        0: 'license_plate'
    }
}

with open('/content/license_plates.yaml', 'w') as f:
    yaml.dump(data_config, f, default_flow_style=False)

# %%
from ultralytics import YOLO

# En appelant jus
# te le modèle, Ultralytics tente de le télécharger
# depuis leurs serveurs (GitHub Assets)
model = YOLO("yolo12n.pt")
print("Téléchargement réussi !")

# %%
from ultralytics import YOLO

# Charger YOLOv12 Nano
model = YOLO('content/yolo12n.pt')

# Entraîner
results = model.train(
    data='/content/license_plates.yaml',
    epochs=20,
    imgsz=640,
    batch=32,
    device=0,
    fraction=0.075
)

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/colab_train_Yolov12/weights/best.pt') # Ton modèle entraîné

# On lance la prédiction sur la vidéo
# save=True est l'argument clé pour générer le fichier vidéo
model.predict(source='../video/voiture_tristan.mp4', save=True, conf=0.5)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 367.7ms
# video 1/1 (frame 2/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 223.7ms
# video 1/1 (frame 3/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 92.6ms
# video 1/1 (frame 4/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 96.4ms
# video 1/1 (frame 5/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 95.9ms
# video 1/1 (frame 6/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 94.7ms
# video 1/1 (frame 7/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 86.4ms
# video 1/1 (frame 8/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 89.2ms
# video 1/1 (frame 9/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 86.3ms
# video 1/1 (frame 10/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 85.2ms
# video 1/1 (frame 11/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 74.6ms
# video 1/1 (frame 12/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 71.1ms
# video 1/1 (frame 13/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 71.7ms
# video 1/1 (frame 14/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 74.5ms
# video 1/1 (frame 15/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 70.8ms
# video 1/1 (frame 16/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 104.1ms
# video 1/1 (frame 17/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 154.4ms
# video 1/1 (frame 18/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 89.8ms
# video 1/1 (frame 19/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 121.4ms
# video 1/1 (frame 20/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 113.3ms
# video 1/1 (frame 21/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 96.9ms
# video 1/1 (frame 22/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 92.0ms
# video 1/1 (frame 23/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 75.7ms
# video 1/1 (frame 24/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 75.2ms
# video 1/1 (frame 25/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 222.4ms
# video 1/1 (frame 26/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 198.2ms
# video 1/1 (frame 27/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 200.8ms
# video 1/1 (frame 28/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 85.5ms
# video 1/1 (frame 29/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 67.5ms
# video 1/1 (frame 30/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 52.9ms
# video 1/1 (frame 31/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 60.5ms
# video 1/1 (frame 32/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 69.7ms
# video 1/1 (frame 33/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 80.5ms
# video 1/1 (frame 34/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 78.5ms
# video 1/1 (frame 35/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 78.1ms
# video 1/1 (frame 36/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 94.0ms
# video 1/1 (frame 37/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 97.6ms
# video 1/1 (frame 38/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 80.1ms
# video 1/1 (frame 39/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 77.0ms
# video 1/1 (frame 40/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 97.2ms
# video 1/1 (frame 41/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 79.7ms
# video 1/1 (frame 42/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 71.0ms
# video 1/1 (frame 43/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 87.1ms
# video 1/1 (frame 44/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 90.3ms
# video 1/1 (frame 45/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 84.4ms
# video 1/1 (frame 46/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 84.1ms
# video 1/1 (frame 47/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate,
151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 160.7ms
# video 1/1 (frame 123/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 69.3ms
# video 1/1 (frame 124/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 74.5ms
# video 1/1 (frame 125/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 75.0ms
# video 1/1 (frame 126/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 62.2ms
# video 1/1 (frame 127/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 68.4ms
# video 1/1 (frame 128/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 85.2ms
# video 1/1 (frame 129/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 91.5ms
# video 1/1 (frame 130/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 79.6ms
# video 1/1 (frame 131/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 77.0ms
# video 1/1 (frame 132/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 85.1ms
# video 1/1 (frame 133/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 83.7ms
# video 1/1 (frame 134/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 59.8ms
# video 1/1 (frame 135/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 50.6ms
# video 1/1 (frame 136/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 61.8ms
# video 1/1 (frame 137/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 73.4ms
# video 1/1 (frame 138/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 84.9ms
# video 1/1 (frame 139/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 73.7ms
# video 1/1 (frame 140/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 68.1ms
# video 1/1 (frame 141/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 104.2ms
# video 1/1 (frame 142/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 100.2ms
# video 1/1 (frame 143/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 71.8ms
# video 1/1 (frame 144/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 194.5ms
# video 1/1 (frame 145/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 100.2ms
# video 1/1 (frame 146/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 (no detections), 89.1ms
# video 1/1 (frame 147/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 108.1ms
# video 1/1 (frame 148/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 83.1ms
# video 1/1 (frame 149/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 70.2ms
# video 1/1 (frame 150/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 79.9ms
# video 1/1 (frame 151/151) c:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\..\video\voiture_tristan.mp4: 640x384 1 license_plate, 127.4ms
# Speed: 3.5ms preprocess, 95.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to C:\Users\celes\OneDrive\Documents\ENTPE\3A\ICVIS\ICVIS_project\notebooks\runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[232, 220, 206],
#          [232, 220, 206],
#          [232, 220, 206],
#          ...,
#          [ 81,  85,  87],
#          [ 81,  85,  87],
#          [ 78,  82,  84]],
#
#         [[232, 220, 206],
#          [232, 220, 206],
#          [232, 220, 206],
#          ...,
#          [ 80,  84,  86],
#          [ 78,  82,  84],
#          [ 78,  82,  84]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 78,  82,  84],
#          [ 78,  82,  84]],
#
#         ...,
#
#         [[108, 111, 109],
#          [115, 118, 116],
#          [122, 125, 123],
#          ...,
#          [ 98,  99,  94],
#          [ 88,  89,  84],
#          [ 95,  96,  91]],
#
#         [[116, 119, 117],
#          [119, 122, 120],
#          [122, 125, 123],
#          ...,
#          [111, 112, 107],
#          [115, 116, 111],
#          [115, 116, 111]],
#
#         [[120, 123, 121],
#          [120, 123, 121],
#          [120, 123, 121],
#          ...,
#          [104, 105, 100],
#          [107, 108, 103],
#          [105, 106, 101]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 25.32899999999927, 'inference': 367.6533999999947, 'postprocess': 12.142599999990011},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 82,  86,  88],
#          [ 81,  85,  87],
#          [ 77,  81,  83]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 81,  85,  87],
#          [ 80,  84,  86],
#          [ 78,  82,  84]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 80,  84,  86],
#          [ 81,  85,  87]],
#
#         ...,
#
#         [[116, 119, 117],
#          [120, 123, 121],
#          [122, 125, 123],
#          ...,
#          [ 78,  78,  76],
#          [ 81,  81,  79],
#          [ 85,  85,  83]],
#
#         [[105, 108, 106],
#          [104, 107, 105],
#          [104, 107, 105],
#          ...,
#          [ 98,  98,  96],
#          [105, 105, 103],
#          [109, 109, 107]],
#
#         [[102, 105, 103],
#          [102, 105, 103],
#          [ 94,  97,  95],
#          ...,
#          [110, 110, 108],
#          [112, 112, 110],
#          [112, 112, 110]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 3.186800000008816, 'inference': 223.73600000000238, 'postprocess': 0.7844000000005735},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 82,  86,  88],
#          [ 80,  84,  86],
#          [ 77,  81,  83]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 81,  85,  87],
#          [ 80,  84,  86],
#          [ 78,  82,  84]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 80,  84,  86],
#          [ 81,  85,  87]],
#
#         ...,
#
#         [[137, 140, 138],
#          [139, 142, 140],
#          [144, 147, 145],
#          ...,
#          [119, 116, 115],
#          [114, 111, 110],
#          [109, 106, 105]],
#
#         [[137, 140, 138],
#          [130, 133, 131],
#          [122, 125, 123],
#          ...,
#          [138, 135, 134],
#          [133, 130, 129],
#          [131, 128, 127]],
#
#         [[104, 107, 105],
#          [ 91,  94,  92],
#          [ 76,  79,  77],
#          ...,
#          [125, 122, 121],
#          [120, 117, 116],
#          [118, 115, 114]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.3989999999969314, 'inference': 92.58429999999862, 'postprocess': 7.641199999994797},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[235, 223, 209],
#          [235, 223, 209],
#          [235, 223, 209],
#          ...,
#          [ 81,  85,  87],
#          [ 78,  82,  84],
#          [ 76,  80,  82]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 78,  82,  84],
#          [ 76,  80,  82]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 78,  82,  84],
#          [ 76,  80,  82]],
#
#         ...,
#
#         [[105, 108, 106],
#          [ 95,  98,  96],
#          [ 97, 100,  98],
#          ...,
#          [107, 109, 102],
#          [104, 106,  99],
#          [100, 102,  95]],
#
#         [[108, 111, 109],
#          [101, 104, 102],
#          [101, 104, 102],
#          ...,
#          [105, 105, 103],
#          [109, 109, 107],
#          [112, 112, 110]],
#
#         [[116, 119, 117],
#          [135, 138, 136],
#          [135, 138, 136],
#          ...,
#          [104, 104, 102],
#          [114, 114, 112],
#          [123, 123, 121]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.681600000002504, 'inference': 96.35550000000137, 'postprocess': 0.7063000000044894},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[235, 223, 209],
#          [235, 223, 209],
#          [235, 223, 209],
#          ...,
#          [ 81,  85,  87],
#          [ 77,  81,  83],
#          [ 77,  81,  83]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 77,  81,  83],
#          [ 76,  80,  82]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 77,  81,  83],
#          [ 75,  79,  81]],
#
#         ...,
#
#         [[115, 118, 116],
#          [112, 115, 113],
#          [ 94,  97,  95],
#          ...,
#          [110, 112, 105],
#          [108, 110, 103],
#          [100, 102,  95]],
#
#         [[114, 117, 115],
#          [102, 105, 103],
#          [111, 114, 112],
#          ...,
#          [ 95,  95,  93],
#          [ 97,  97,  95],
#          [ 89,  89,  87]],
#
#         [[105, 108, 106],
#          [ 97, 100,  98],
#          [118, 121, 119],
#          ...,
#          [ 86,  86,  84],
#          [ 88,  88,  86],
#          [ 89,  89,  87]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.105600000007257, 'inference': 95.87889999998822, 'postprocess': 0.7074000000102387},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 81,  85,  87],
#          [ 78,  82,  84],
#          [ 78,  82,  84]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 78,  82,  84],
#          [ 78,  82,  84],
#          [ 77,  81,  83]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 77,  81,  83],
#          [ 77,  81,  83],
#          [ 76,  80,  82]],
#
#         ...,
#
#         [[ 83,  86,  84],
#          [ 80,  83,  81],
#          [ 78,  81,  79],
#          ...,
#          [100, 101,  96],
#          [ 96,  97,  92],
#          [ 98,  99,  94]],
#
#         [[102, 105, 103],
#          [119, 122, 120],
#          [125, 128, 126],
#          ...,
#          [110, 111, 106],
#          [104, 105, 100],
#          [103, 104,  99]],
#
#         [[169, 172, 170],
#          [192, 195, 193],
#          [193, 196, 194],
#          ...,
#          [109, 110, 105],
#          [104, 105, 100],
#          [102, 103,  98]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.7417000000014013, 'inference': 94.73489999999174, 'postprocess': 0.8799999999951069},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[231, 219, 205],
#          [231, 219, 205],
#          [231, 219, 205],
#          ...,
#          [ 80,  84,  86],
#          [ 80,  84,  86],
#          [ 80,  84,  86]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 78,  82,  84],
#          [ 78,  82,  84],
#          [ 78,  82,  84]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 77,  81,  83],
#          [ 77,  81,  83],
#          [ 77,  81,  83]],
#
#         ...,
#
#         [[ 71,  74,  72],
#          [ 73,  76,  74],
#          [ 83,  86,  84],
#          ...,
#          [115, 116, 111],
#          [110, 111, 106],
#          [110, 111, 106]],
#
#         [[ 94,  97,  95],
#          [ 99, 102, 100],
#          [ 99, 102, 100],
#          ...,
#          [112, 113, 108],
#          [ 98,  99,  94],
#          [ 83,  84,  79]],
#
#         [[101, 104, 102],
#          [111, 114, 112],
#          [111, 114, 112],
#          ...,
#          [109, 110, 105],
#          [ 90,  91,  86],
#          [ 76,  77,  72]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.5152000000048247, 'inference': 86.43449999999575, 'postprocess': 0.7722000000001117},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[235, 223, 209],
#          [235, 223, 209],
#          [235, 223, 209],
#          ...,
#          [ 80,  84,  86],
#          [ 80,  84,  86],
#          [ 80,  84,  86]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [235, 223, 209],
#          ...,
#          [ 80,  84,  86],
#          [ 78,  82,  84],
#          [ 78,  82,  84]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 78,  82,  84],
#          [ 77,  81,  83],
#          [ 77,  81,  83]],
#
#         ...,
#
#         [[ 95,  98,  96],
#          [113, 116, 114],
#          [126, 129, 127],
#          ...,
#          [ 89,  90,  85],
#          [ 78,  79,  74],
#          [118, 119, 114]],
#
#         [[ 87,  90,  88],
#          [ 82,  85,  83],
#          [ 82,  85,  83],
#          ...,
#          [ 80,  81,  76],
#          [ 81,  82,  77],
#          [128, 129, 124]],
#
#         [[ 86,  89,  87],
#          [ 83,  86,  84],
#          [ 88,  91,  89],
#          ...,
#          [ 72,  73,  68],
#          [ 86,  87,  82],
#          [132, 133, 128]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.636899999998832, 'inference': 89.17220000000725, 'postprocess': 0.8676000000065187},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[235, 223, 209],
#          [235, 223, 209],
#          [235, 223, 209],
#          ...,
#          [ 81,  85,  87],
#          [ 78,  82,  84],
#          [ 77,  81,  83]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 77,  81,  83],
#          [ 76,  80,  82]],
#
#         [[235, 223, 209],
#          [235, 223, 209],
#          [235, 223, 209],
#          ...,
#          [ 77,  81,  83],
#          [ 76,  80,  82],
#          [ 76,  80,  82]],
#
#         ...,
#
#         [[113, 116, 114],
#          [114, 117, 115],
#          [114, 117, 115],
#          ...,
#          [132, 133, 128],
#          [124, 125, 120],
#          [ 93,  94,  89]],
#
#         [[112, 115, 113],
#          [112, 115, 113],
#          [121, 124, 122],
#          ...,
#          [171, 172, 167],
#          [159, 160, 155],
#          [117, 118, 113]],
#
#         [[ 94,  97,  95],
#          [104, 107, 105],
#          [116, 119, 117],
#          ...,
#          [181, 182, 177],
#          [183, 184, 179],
#          [151, 152, 147]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.4638999999950784, 'inference': 86.29979999999193, 'postprocess': 0.8752999999899203},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[235, 223, 209],
#          [235, 223, 209],
#          [235, 223, 209],
#          ...,
#          [ 78,  82,  84],
#          [ 78,  82,  84],
#          [ 78,  82,  84]],
#
#         [[235, 223, 209],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 78,  82,  84],
#          [ 77,  81,  83],
#          [ 77,  81,  83]],
#
#         [[235, 223, 209],
#          [235, 223, 209],
#          [235, 223, 209],
#          ...,
#          [ 77,  81,  83],
#          [ 77,  81,  83],
#          [ 77,  81,  83]],
#
#         ...,
#
#         [[112, 115, 113],
#          [100, 103, 101],
#          [100, 103, 101],
#          ...,
#          [ 74,  75,  70],
#          [ 73,  74,  69],
#          [ 79,  80,  75]],
#
#         [[111, 114, 112],
#          [ 84,  87,  85],
#          [ 80,  83,  81],
#          ...,
#          [ 94,  95,  90],
#          [ 88,  89,  84],
#          [ 85,  86,  81]],
#
#         [[107, 110, 108],
#          [100, 103, 101],
#          [ 88,  91,  89],
#          ...,
#          [110, 111, 106],
#          [ 93,  94,  89],
#          [ 93,  94,  89]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 3.352100000000746, 'inference': 85.19080000000656, 'postprocess': 0.8052000000020598},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[235, 223, 209],
#          [235, 223, 209],
#          [234, 222, 208],
#          ...,
#          [ 78,  82,  84],
#          [ 78,  82,  84],
#          [ 80,  84,  86]],
#
#         [[235, 223, 209],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 80,  84,  86],
#          [ 78,  82,  84],
#          [ 78,  82,  84]],
#
#         [[235, 223, 209],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 78,  82,  84],
#          [ 78,  82,  84],
#          [ 77,  81,  83]],
#
#         ...,
#
#         [[106, 109, 107],
#          [101, 104, 102],
#          [ 86,  89,  87],
#          ...,
#          [ 87,  88,  83],
#          [ 89,  90,  85],
#          [ 85,  86,  81]],
#
#         [[107, 110, 108],
#          [ 93,  96,  94],
#          [ 80,  83,  81],
#          ...,
#          [ 85,  86,  81],
#          [ 89,  90,  85],
#          [ 87,  88,  83]],
#
#         [[113, 116, 114],
#          [121, 124, 122],
#          [112, 115, 113],
#          ...,
#          [ 91,  92,  87],
#          [100, 101,  96],
#          [ 98,  99,  94]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.240000000000464, 'inference': 74.63239999999871, 'postprocess': 0.6776999999971167},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[235, 223, 209],
#          [235, 223, 209],
#          [234, 222, 208],
#          ...,
#          [ 78,  82,  84],
#          [ 77,  81,  83],
#          [ 77,  81,  83]],
#
#         [[235, 223, 209],
#          [235, 223, 209],
#          [234, 222, 208],
#          ...,
#          [ 77,  81,  83],
#          [ 77,  81,  83],
#          [ 76,  80,  82]],
#
#         [[235, 223, 209],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 77,  81,  83],
#          [ 77,  81,  83],
#          [ 77,  81,  83]],
#
#         ...,
#
#         [[ 87,  90,  88],
#          [ 92,  95,  93],
#          [ 84,  87,  85],
#          ...,
#          [ 82,  83,  78],
#          [ 89,  90,  85],
#          [102, 103,  98]],
#
#         [[ 72,  75,  73],
#          [ 80,  83,  81],
#          [ 91,  94,  92],
#          ...,
#          [ 86,  87,  82],
#          [ 96,  97,  92],
#          [119, 120, 115]],
#
#         [[ 87,  90,  88],
#          [ 94,  97,  95],
#          [108, 111, 109],
#          ...,
#          [ 96,  97,  92],
#          [ 96,  97,  92],
#          [117, 118, 113]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.617899999989959, 'inference': 71.07550000000629, 'postprocess': 0.7896000000044978},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[232, 222, 208],
#          [232, 222, 208],
#          [232, 222, 208],
#          ...,
#          [ 77,  81,  83],
#          [ 76,  80,  82],
#          [ 75,  79,  81]],
#
#         [[230, 220, 206],
#          [230, 220, 206],
#          [230, 220, 206],
#          ...,
#          [ 76,  80,  82],
#          [ 76,  80,  82],
#          [ 75,  79,  81]],
#
#         [[232, 222, 208],
#          [232, 222, 208],
#          [232, 222, 208],
#          ...,
#          [ 76,  80,  82],
#          [ 76,  80,  82],
#          [ 76,  80,  82]],
#
#         ...,
#
#         [[ 76,  79,  77],
#          [ 91,  94,  92],
#          [ 83,  86,  84],
#          ...,
#          [104, 105, 100],
#          [103, 104,  99],
#          [ 93,  94,  89]],
#
#         [[ 82,  85,  83],
#          [108, 111, 109],
#          [119, 122, 120],
#          ...,
#          [124, 125, 120],
#          [131, 132, 127],
#          [125, 126, 121]],
#
#         [[105, 108, 106],
#          [130, 133, 131],
#          [114, 117, 115],
#          ...,
#          [123, 124, 119],
#          [137, 138, 133],
#          [138, 139, 134]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.408500000001368, 'inference': 71.65849999999807, 'postprocess': 0.4401999999998907},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 77,  81,  83],
#          [ 76,  80,  82],
#          [ 76,  80,  82]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 77,  81,  83],
#          [ 77,  81,  83],
#          [ 76,  80,  82]],
#
#         [[234, 222, 208],
#          [234, 222, 208],
#          [234, 222, 208],
#          ...,
#          [ 76,  80,  82],
#          [ 76,  80,  82],
#          [ 75,  79,  81]],
#
#         ...,
#
#         [[116, 119, 117],
#          [111, 114, 112],
#          [ 76,  79,  77],
#          ...,
#          [102, 103,  98],
#          [ 96,  97,  92],
#          [ 98,  99,  94]],
#
#         [[111, 114, 112],
#          [ 93,  96,  94],
#          [ 70,  73,  71],
#          ...,
#          [137, 138, 133],
#          [125, 126, 121],
#          [117, 118, 113]],
#
#         [[ 87,  90,  88],
#          [105, 108, 106],
#          [107, 110, 108],
#          ...,
#          [144, 145, 140],
#          [126, 127, 122],
#          [115, 116, 111]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
# ...
#          [237, 220, 214],
#          [236, 219, 213],
#          [237, 220, 214]],
#
#         [[188, 199, 207],
#          [188, 199, 207],
#          [190, 198, 207],
#          ...,
#          [236, 219, 213],
#          [236, 219, 213],
#          [236, 219, 213]],
#
#         ...,
#
#         [[ 51,  49,  54],
#          [ 51,  49,  54],
#          [ 51,  49,  54],
#          ...,
#          [ 96,  95,  97],
#          [108, 107, 109],
#          [110, 109, 111]],
#
#         [[ 51,  49,  54],
#          [ 51,  49,  54],
#          [ 51,  49,  54],
#          ...,
#          [ 93,  92,  94],
#          [102, 101, 103],
#          [112, 111, 113]],
#
#         [[ 51,  49,  54],
#          [ 51,  49,  54],
#          [ 51,  49,  54],
#          ...,
#          [101, 100, 102],
#          [110, 109, 111],
#          [119, 118, 120]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.7305000000126256, 'inference': 100.24930000000154, 'postprocess': 0.513600000004999},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[186, 195, 201],
#          [186, 195, 201],
#          [186, 195, 201],
#          ...,
#          [232, 218, 211],
#          [232, 218, 211],
#          [232, 218, 211]],
#
#         [[189, 198, 204],
#          [189, 198, 204],
#          [189, 198, 204],
#          ...,
#          [231, 217, 210],
#          [231, 217, 210],
#          [231, 217, 210]],
#
#         [[189, 198, 204],
#          [189, 198, 204],
#          [189, 198, 204],
#          ...,
#          [231, 217, 210],
#          [231, 217, 210],
#          [231, 217, 210]],
#
#         ...,
#
#         [[ 83,  83,  83],
#          [ 82,  82,  82],
#          [ 81,  81,  81],
#          ...,
#          [ 95,  91,  94],
#          [ 92,  88,  91],
#          [ 97,  93,  96]],
#
#         [[ 83,  83,  83],
#          [ 82,  82,  82],
#          [ 82,  82,  82],
#          ...,
#          [ 99,  95,  98],
#          [ 99,  95,  98],
#          [103,  99, 102]],
#
#         [[ 83,  83,  83],
#          [ 83,  83,  83],
#          [ 82,  82,  82],
#          ...,
#          [104, 100, 103],
#          [100,  96,  99],
#          [ 98,  94,  97]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.643800000001306, 'inference': 71.82109999999398, 'postprocess': 0.497099999989814},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[182, 190, 199],
#          [186, 194, 203],
#          [186, 194, 203],
#          ...,
#          [230, 216, 209],
#          [230, 216, 209],
#          [230, 216, 209]],
#
#         [[177, 185, 194],
#          [174, 182, 191],
#          [172, 180, 189],
#          ...,
#          [230, 216, 209],
#          [230, 216, 209],
#          [230, 216, 209]],
#
#         [[157, 165, 174],
#          [153, 161, 170],
#          [147, 155, 164],
#          ...,
#          [231, 214, 208],
#          [231, 214, 208],
#          [231, 214, 208]],
#
#         ...,
#
#         [[ 35,  31,  34],
#          [ 35,  31,  34],
#          [ 35,  31,  34],
#          ...,
#          [ 76,  75,  77],
#          [ 81,  80,  82],
#          [ 96,  95,  97]],
#
#         [[ 35,  31,  34],
#          [ 35,  31,  34],
#          [ 35,  31,  34],
#          ...,
#          [ 81,  80,  82],
#          [ 81,  80,  82],
#          [ 95,  94,  96]],
#
#         [[ 36,  32,  35],
#          [ 36,  32,  35],
#          [ 36,  32,  35],
#          ...,
#          [ 79,  78,  80],
#          [ 79,  78,  80],
#          [ 85,  84,  86]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.6235999999926207, 'inference': 194.47999999999865, 'postprocess': 0.6453999999962434},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[180, 191, 199],
#          [180, 191, 199],
#          [180, 191, 199],
#          ...,
#          [227, 213, 206],
#          [227, 213, 206],
#          [227, 213, 206]],
#
#         [[179, 190, 198],
#          [179, 190, 198],
#          [179, 190, 198],
#          ...,
#          [228, 214, 207],
#          [228, 214, 207],
#          [228, 214, 207]],
#
#         [[179, 190, 198],
#          [179, 190, 198],
#          [179, 190, 198],
#          ...,
#          [229, 213, 205],
#          [229, 213, 205],
#          [229, 213, 205]],
#
#         ...,
#
#         [[ 60,  56,  59],
#          [ 59,  55,  58],
#          [ 59,  55,  58],
#          ...,
#          [ 94,  93,  95],
#          [110, 109, 111],
#          [128, 127, 129]],
#
#         [[ 59,  55,  58],
#          [ 54,  50,  53],
#          [ 54,  50,  53],
#          ...,
#          [ 93,  92,  94],
#          [ 96,  95,  97],
#          [109, 108, 110]],
#
#         [[ 63,  59,  62],
#          [ 55,  51,  54],
#          [ 52,  48,  51],
#          ...,
#          [ 98,  97,  99],
#          [ 97,  96,  98],
#          [ 98,  97,  99]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 4.18059999999798, 'inference': 100.19069999999886, 'postprocess': 0.6949999999932288},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[177, 186, 192],
#          [177, 186, 192],
#          [177, 186, 192],
#          ...,
#          [222, 208, 201],
#          [222, 208, 201],
#          [222, 208, 201]],
#
#         [[177, 186, 192],
#          [177, 186, 192],
#          [177, 186, 192],
#          ...,
#          [222, 208, 201],
#          [222, 208, 201],
#          [222, 208, 201]],
#
#         [[177, 186, 192],
#          [177, 186, 192],
#          [177, 186, 192],
#          ...,
#          [222, 208, 201],
#          [222, 208, 201],
#          [222, 208, 201]],
#
#         ...,
#
#         [[ 73,  69,  72],
#          [ 78,  74,  77],
#          [ 84,  80,  83],
#          ...,
#          [ 89,  88,  90],
#          [ 98,  97,  99],
#          [103, 102, 104]],
#
#         [[ 70,  66,  69],
#          [ 76,  72,  75],
#          [ 84,  80,  83],
#          ...,
#          [ 85,  84,  86],
#          [ 91,  90,  92],
#          [ 97,  96,  98]],
#
#         [[ 69,  65,  68],
#          [ 75,  71,  74],
#          [ 84,  80,  83],
#          ...,
#          [ 87,  86,  88],
#          [ 86,  85,  87],
#          [ 86,  85,  87]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.437499999999204, 'inference': 89.09680000000719, 'postprocess': 0.4808999999994512},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[177, 186, 192],
#          [177, 186, 192],
#          [177, 186, 192],
#          ...,
#          [224, 210, 203],
#          [224, 210, 203],
#          [224, 210, 203]],
#
#         [[177, 186, 192],
#          [177, 186, 192],
#          [177, 186, 192],
#          ...,
#          [227, 213, 206],
#          [225, 211, 204],
#          [225, 211, 204]],
#
#         [[177, 186, 192],
#          [177, 186, 192],
#          [177, 186, 192],
#          ...,
#          [226, 210, 202],
#          [226, 210, 202],
#          [226, 210, 202]],
#
#         ...,
#
#         [[ 85,  83,  88],
#          [ 72,  70,  75],
#          [ 64,  62,  67],
#          ...,
#          [ 98,  97,  99],
#          [ 98,  97,  99],
#          [100,  99, 101]],
#
#         [[ 72,  70,  75],
#          [ 64,  62,  67],
#          [ 60,  58,  63],
#          ...,
#          [103, 102, 104],
#          [108, 107, 109],
#          [107, 106, 108]],
#
#         [[ 65,  63,  68],
#          [ 59,  57,  62],
#          [ 58,  56,  61],
#          ...,
#          [104, 103, 105],
#          [109, 108, 110],
#          [107, 106, 108]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.590299999994272, 'inference': 108.10650000000521, 'postprocess': 1.0636000000090462},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[171, 180, 186],
#          [171, 180, 186],
#          [171, 180, 186],
#          ...,
#          [224, 210, 203],
#          [224, 210, 203],
#          [224, 210, 203]],
#
#         [[171, 180, 186],
#          [171, 180, 186],
#          [171, 180, 186],
#          ...,
#          [227, 213, 206],
#          [225, 211, 204],
#          [225, 211, 204]],
#
#         [[172, 181, 187],
#          [172, 181, 187],
#          [172, 181, 187],
#          ...,
#          [226, 210, 202],
#          [226, 210, 202],
#          [226, 210, 202]],
#
#         ...,
#
#         [[110, 105, 111],
#          [126, 121, 127],
#          [132, 127, 133],
#          ...,
#          [100,  99, 101],
#          [ 94,  93,  95],
#          [ 88,  87,  89]],
#
#         [[130, 125, 131],
#          [137, 132, 138],
#          [131, 126, 132],
#          ...,
#          [107, 106, 108],
#          [105, 104, 106],
#          [ 95,  94,  96]],
#
#         [[133, 128, 134],
#          [132, 127, 133],
#          [123, 118, 124],
#          ...,
#          [104, 103, 105],
#          [108, 107, 109],
#          [104, 103, 105]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.726000000009776, 'inference': 83.08470000000057, 'postprocess': 0.949099999999703},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[174, 183, 189],
#          [174, 183, 189],
#          [174, 183, 189],
#          ...,
#          [224, 210, 203],
#          [224, 210, 203],
#          [224, 210, 203]],
#
#         [[174, 183, 189],
#          [174, 183, 189],
#          [174, 183, 189],
#          ...,
#          [225, 211, 204],
#          [225, 211, 204],
#          [225, 211, 204]],
#
#         [[174, 183, 189],
#          [174, 183, 189],
#          [174, 183, 189],
#          ...,
#          [226, 210, 202],
#          [226, 210, 202],
#          [226, 210, 202]],
#
#         ...,
#
#         [[ 85,  79,  82],
#          [ 85,  79,  82],
#          [ 87,  81,  84],
#          ...,
#          [ 91,  90,  92],
#          [ 93,  92,  94],
#          [ 94,  93,  95]],
#
#         [[ 98,  92,  95],
#          [ 98,  92,  95],
#          [101,  95,  98],
#          ...,
#          [ 88,  87,  89],
#          [ 88,  87,  89],
#          [ 89,  88,  90]],
#
#         [[100,  94,  97],
#          [101,  95,  98],
#          [100,  94,  97],
#          ...,
#          [ 85,  84,  86],
#          [ 82,  81,  83],
#          [ 83,  82,  84]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 1.9922000000036633, 'inference': 70.24829999998872, 'postprocess': 0.778999999994312},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[169, 178, 184],
#          [169, 178, 184],
#          [168, 177, 183],
#          ...,
#          [227, 213, 206],
#          [224, 210, 203],
#          [224, 210, 203]],
#
#         [[168, 177, 183],
#          [168, 177, 183],
#          [168, 177, 183],
#          ...,
#          [227, 213, 206],
#          [224, 210, 203],
#          [224, 210, 203]],
#
#         [[169, 178, 184],
#          [169, 178, 184],
#          [170, 179, 185],
#          ...,
#          [227, 213, 206],
#          [224, 210, 203],
#          [224, 210, 203]],
#
#         ...,
#
#         [[119, 119, 119],
#          [116, 116, 116],
#          [112, 112, 112],
#          ...,
#          [ 91,  90,  92],
#          [ 91,  90,  92],
#          [ 93,  92,  94]],
#
#         [[111, 111, 111],
#          [110, 110, 110],
#          [109, 109, 109],
#          ...,
#          [ 88,  87,  89],
#          [ 93,  92,  94],
#          [ 96,  95,  97]],
#
#         [[110, 110, 110],
#          [109, 109, 109],
#          [107, 107, 107],
#          ...,
#          [ 93,  92,  94],
#          [101, 100, 102],
#          [103, 102, 104]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.332100000003834, 'inference': 79.87930000000176, 'postprocess': 1.0761999999999716},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'license_plate'}
#  obb: None
#  orig_img: array([[[172, 181, 187],
#          [172, 181, 187],
#          [174, 183, 189],
#          ...,
#          [227, 213, 206],
#          [227, 213, 206],
#          [225, 211, 204]],
#
#         [[172, 181, 187],
#          [174, 183, 189],
#          [174, 183, 189],
#          ...,
#          [227, 213, 206],
#          [227, 213, 206],
#          [225, 211, 204]],
#
#         [[172, 181, 187],
#          [174, 183, 189],
#          [174, 183, 189],
#          ...,
#          [227, 213, 206],
#          [227, 213, 206],
#          [225, 211, 204]],
#
#         ...,
#
#         [[113, 114, 119],
#          [108, 109, 114],
#          [106, 107, 112],
#          ...,
#          [111, 110, 112],
#          [110, 109, 111],
#          [104, 103, 105]],
#
#         [[109, 110, 115],
#          [111, 112, 117],
#          [107, 108, 113],
#          ...,
#          [116, 115, 117],
#          [109, 108, 110],
#          [ 98,  97,  99]],
#
#         [[ 98,  99, 104],
#          [104, 105, 110],
#          [106, 107, 112],
#          ...,
#          [112, 111, 113],
#          [111, 110, 112],
#          [107, 106, 108]]], dtype=uint8)
#  orig_shape: (1920, 1080)
#  path: 'c:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\..\\video\\voiture_tristan.mp4'
#  probs: None
#  save_dir: 'C:\\Users\\celes\\OneDrive\\Documents\\ENTPE\\3A\\ICVIS\\ICVIS_project\\notebooks\\runs\\detect\\predict'
#  speed: {'preprocess': 2.306599999997161, 'inference': 127.3567000000071, 'postprocess': 0.9775999999988016}]

# %%
import cv2
import easyocr
from ultralytics import YOLO

# 1. Initialisation (Modèle + Lecteur OCR)
model = YOLO('runs/detect/colab_train_Yolov12/weights/best.pt')  # Votre modèle entraîné
reader = easyocr.Reader(['en']) # 'en' pour les caractères latins

video_path = '../video/voiture_tristan.mp4'
cap = cv2.VideoCapture(video_path)

# Préparation de l'écriture de la vidéo finale
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('../video/resultat_final.mp4', fourcc, 30.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # 2. Détection avec YOLO
    results = model(frame, conf=0.5)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        # 3. Découpage de la plaque (Crop)
        plate_crop = frame[int(y1):int(y2), int(x1):int(x2)]

        if plate_crop.size > 0:
            # 4. Lecture de la plaque avec EasyOCR
            ocr_result = reader.readtext(plate_crop)
            
            if ocr_result:
                plate_text = ocr_result[0][-2].upper() # Récupère le texte en majuscules

                # 5. Affichage dans le coin supérieur gauche
                # Rectangle de fond pour la lisibilité
                cv2.rectangle(frame, (10, 10), (400, 80), (0, 0, 0), -1)
                # Texte de la plaque
                cv2.putText(frame, f"PLAQUE : {plate_text}", (20, 60), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)

                # Dessiner aussi le cadre autour de la plaque sur la voiture
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

    # Affichage en direct (optionnel)
    # cv2.imshow('Detection et Lecture', frame)
    out.write(frame) # Sauvegarde chaque image dans la vidéo finale

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
print("Vidéo terminée et enregistrée sous '../video/resultat_final.mp4'")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 0: 640x384 (no detections), 523.6ms
# Speed: 14.0ms preprocess, 523.6ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 86.4ms
# Speed: 3.8ms preprocess, 86.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 127.3ms
# Speed: 3.0ms preprocess, 127.3ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 75.3ms
# Speed: 2.8ms preprocess, 75.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 115.1ms
# Speed: 4.3ms preprocess, 115.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 156.4ms
# Speed: 6.3ms preprocess, 156.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 98.7ms
# Speed: 3.5ms preprocess, 98.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 100.8ms
# Speed: 3.7ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 78.4ms
# Speed: 3.2ms preprocess, 78.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 86.4ms
# Speed: 2.5ms preprocess, 86.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 84.3ms
# Speed: 3.2ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 76.7ms
# Speed: 2.4ms preprocess, 76.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 69.5ms
# Speed: 3.2ms preprocess, 69.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 71
1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 57.9ms
# Speed: 2.3ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 55.8ms
# Speed: 2.4ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 54.9ms
# Speed: 2.4ms preprocess, 54.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 54.9ms
# Speed: 2.4ms preprocess, 54.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 51.7ms
# Speed: 2.6ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 55.3ms
# Speed: 2.6ms preprocess, 55.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 54.7ms
# Speed: 2.1ms preprocess, 54.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 54.5ms
# Speed: 2.4ms preprocess, 54.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 66.5ms
# Speed: 2.7ms preprocess, 66.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 50.8ms
# Speed: 2.8ms preprocess, 50.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 59.4ms
# Speed: 2.7ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 license_plate, 59.4ms
# Speed: 2.8ms preprocess, 59.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Vidéo terminée et enregistrée sous '../video/resultat_final.mp4'

# %%
import cv2
import easyocr
import os
from ultralytics import YOLO
from collections import Counter

# 1. Chargement des modèles
model = YOLO('runs/detect/colab_train_Yolov12/weights/best.pt')  # Assurez-vous que le fichier est dans le même dossier
reader = easyocr.Reader(['en'], gpu=True) # Utilise le GPU si disponible

# 2. Configuration Vidéo
video_path = '../video/voiture_tristan.mp4'
if not os.path.exists(video_path):
    print(f"Erreur : Le fichier {video_path} est introuvable.")
    exit()

cap = cv2.VideoCapture(video_path)
width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps    = int(cap.get(cv2.CAP_PROP_FPS))

# Préparation de la vidéo de sortie
out = cv2.VideoWriter('../video/resultat_final_stable.mp4', 
                       cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

# --- VARIABLES DE STABILISATION ---
plate_history = []     # Liste pour stocker les dernières lectures
max_history = 30       # Nombre de frames à mémoriser pour le "vote"
stable_text = "En attente..."

print("Analyse en cours... Appuyez sur 'q' pour arrêter.")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # 3. Détection de la plaque avec YOLO
    results = model(frame, conf=0.5, verbose=False)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result
        
        # Découpage (Crop) de la zone de la plaque
        plate_img = frame[int(y1):int(y2), int(x1):int(x2)]
        
        if plate_img.size > 0:
            # 4. Lecture OCR
            ocr_results = reader.readtext(plate_img)
            
            if ocr_results:
                # Récupère le texte, le nettoie et le met en majuscules
                current_read = ocr_results[0][-2].upper().strip()
                
                # Ajout à l'historique pour stabilisation
                plate_history.append(current_read)
                if len(plate_history) > max_history:
                    plate_history.pop(0)

                # 5. SYSTÈME DE VOTE : On prend le texte le plus fréquent
                stable_text = Counter(plate_history).most_common(1)[0][0]

        # Dessiner le cadre vert sur la voiture
        cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

    # 6. AFFICHAGE DANS LE COIN SUPÉRIEUR GAUCHE
    # Fond noir pour la lisibilité
    cv2.rectangle(frame, (0, 0), (600, 100), (0, 0, 0), -1)
    # Texte stabilisé
    cv2.putText(frame, f"PLAQUE : {stable_text}", (20, 65), 
                cv2.FONT_HERSHEY_SIMPLEX, 1.8, (0, 255, 0), 4)

    # 7. Sauvegarde et Visualisation
    out.write(frame)
    
    # NOTE : Si cv2.imshow plante encore, commentez les deux lignes suivantes
    cv2.imshow('Detection de plaque stabilisée', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()
print("Traitement terminé. Vidéo enregistrée sous 'resultat_final_stable.mp4'")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Analyse en cours... Appuyez sur 'q' pour arrêter.
# Traitement terminé. Vidéo enregistrée sous 'resultat_final_stable.mp4'
